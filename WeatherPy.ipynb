# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city + "&appid=" + weather_api_key + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kedrovyy
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | shache
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | puerto narino
# Processing Record 14 of Set 1 | kerman
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | lelydorp
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | wodonga
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | am timan
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | deer lake
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | inirida
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | yulara
# Processing Record 33 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 34 of Set 1 | salihorsk
# Processing Record 35 of Set 1 | mezen
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | paramonga
# Processing Record 40 of Set 1 | jiaohe
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | awjilah
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | saint-paul
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | sohag
# Processing Record 47 of Set 1 | paraiso
# Processing Record 48 of Set 1 | ayagoz
# Processing Record 49 of Set 1 | abu samrah
# Processing Record 50 of Set 1 | yeovil
# Processing Record 0 of Set 2 | rikitea
# Processing Record 1 of Set 2 | mandalon
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | huarmey
# Processing Record 5 of Set 2 | tomohon
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | aksu
# Processing Record 9 of Set 2 | atar
# Processing Record 10 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 2 | yaan
# Processing Record 12 of Set 2 | sisimiut
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | ahipara
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | kendari
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | mananjary
# Processing Record 23 of Set 2 | keti bandar
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | solnechnyy
# Processing Record 27 of Set 2 | ust-kulom
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | gasa
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | los llanos de aridane
# Processing Record 32 of Set 2 | grand gaube
# Processing Record 33 of Set 2 | saint anthony
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | qaracala
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | mindelo
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | comodoro rivadavia
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 0 of Set 3 | istok
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | laurel
# Processing Record 3 of Set 3 | mehamn
# Processing Record 4 of Set 3 | portage
# Processing Record 5 of Set 3 | gold coast
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | nyurba
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | puerto carreno
# Processing Record 11 of Set 3 | hofn
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | laguna
# Processing Record 16 of Set 3 | mokhsogollokh
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | port blair
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | bac lieu
# Processing Record 21 of Set 3 | tautira
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | agropoli
# Processing Record 24 of Set 3 | grindavik
# Processing Record 25 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 3 | nakhon phanom
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | konya
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | matam
# Processing Record 33 of Set 3 | kabul
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | puerto ayora
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | motril
# Processing Record 40 of Set 3 | aksarka
# Processing Record 41 of Set 3 | saint-denis
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | beloha
# Processing Record 44 of Set 3 | ukiah
# Processing Record 45 of Set 3 | yankton
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | tiznit
# Processing Record 49 of Set 3 | cabedelo
# Processing Record 0 of Set 4 | boden
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | eureka
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | dunedin
# Processing Record 7 of Set 4 | gubkinskiy
# Processing Record 8 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | parana
# Processing Record 17 of Set 4 | kapaa
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | shingu
# Processing Record 20 of Set 4 | hithadhoo
# Processing Record 21 of Set 4 | ampanihy
# Processing Record 22 of Set 4 | cobija
# Processing Record 23 of Set 4 | neftekamsk
# Processing Record 24 of Set 4 | chuy
# Processing Record 25 of Set 4 | preobrazheniye
# Processing Record 26 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 4 | yanam
# Processing Record 28 of Set 4 | zhigansk
# Processing Record 29 of Set 4 | burewala
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | dingle
# Processing Record 34 of Set 4 | mikun
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | mont-de-marsan
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | tanshui
# City not found. Skipping...
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | vuktyl
# Processing Record 42 of Set 4 | kimbe
# Processing Record 43 of Set 4 | elbrus
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | pravia
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | greensburg
# Processing Record 49 of Set 4 | yongan
# Processing Record 0 of Set 5 | florenville
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | turukhansk
# Processing Record 3 of Set 5 | nome
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | kibaya
# Processing Record 6 of Set 5 | zaozerne
# Processing Record 7 of Set 5 | port moresby
# Processing Record 8 of Set 5 | puerto ayacucho
# Processing Record 9 of Set 5 | meulaboh
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | shenjiamen
# Processing Record 12 of Set 5 | kovdor
# Processing Record 13 of Set 5 | siimusti
# Processing Record 14 of Set 5 | hammerfest
# Processing Record 15 of Set 5 | nantucket
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | novo aripuana
# Processing Record 18 of Set 5 | dubrovnik
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | namtsy
# Processing Record 21 of Set 5 | alwar
# Processing Record 22 of Set 5 | tome
# Processing Record 23 of Set 5 | huadian
# Processing Record 24 of Set 5 | luganville
# Processing Record 25 of Set 5 | ramanuj ganj
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | kismayo
# Processing Record 28 of Set 5 | maceio
# Processing Record 29 of Set 5 | aljezur
# Processing Record 30 of Set 5 | thompson
# Processing Record 31 of Set 5 | epe
# Processing Record 32 of Set 5 | north bend
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | tilichiki
# Processing Record 35 of Set 5 | karratha
# Processing Record 36 of Set 5 | saint-leu
# Processing Record 37 of Set 5 | mahebourg
# Processing Record 38 of Set 5 | san-pedro
# Processing Record 39 of Set 5 | sakassou
# Processing Record 40 of Set 5 | olafsvik
# Processing Record 41 of Set 5 | antofagasta
# Processing Record 42 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 5 | lima
# Processing Record 44 of Set 5 | bilibino
# Processing Record 45 of Set 5 | makakilo city
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | saint-felicien
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | lanja
# Processing Record 0 of Set 6 | san angelo
# Processing Record 1 of Set 6 | kumluca
# Processing Record 2 of Set 6 | dois riachos
# Processing Record 3 of Set 6 | jumla
# Processing Record 4 of Set 6 | lasa
# Processing Record 5 of Set 6 | marsh harbour
# Processing Record 6 of Set 6 | sunrise
# Processing Record 7 of Set 6 | camacha
# Processing Record 8 of Set 6 | east london
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | machico
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 6 | half moon bay
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | porto-vecchio
# Processing Record 16 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 6 | wewak
# Processing Record 18 of Set 6 | harper
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | buala
# Processing Record 21 of Set 6 | raudeberg
# Processing Record 22 of Set 6 | noumea
# Processing Record 23 of Set 6 | brindisi
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | lenggries
# Processing Record 26 of Set 6 | ous
# Processing Record 27 of Set 6 | kasongo-lunda
# Processing Record 28 of Set 6 | broome
# Processing Record 29 of Set 6 | tecate
# Processing Record 30 of Set 6 | awbari
# Processing Record 31 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | kisangani
# Processing Record 34 of Set 6 | gat
# Processing Record 35 of Set 6 | komatipoort
# Processing Record 36 of Set 6 | kununurra
# Processing Record 37 of Set 6 | bad bentheim
# Processing Record 38 of Set 6 | nylstroom
# City not found. Skipping...
# Processing Record 39 of Set 6 | athens
# Processing Record 40 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 6 | klaksvik
# Processing Record 42 of Set 6 | muisne
# Processing Record 43 of Set 6 | port hardy
# Processing Record 44 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | cayenne
# Processing Record 47 of Set 6 | ribeira grande
# Processing Record 48 of Set 6 | vestmannaeyjar
# Processing Record 49 of Set 6 | pisco
# Processing Record 0 of Set 7 | ilulissat
# Processing Record 1 of Set 7 | otukpo
# Processing Record 2 of Set 7 | carutapera
# Processing Record 3 of Set 7 | cockburn town
# Processing Record 4 of Set 7 | trabzon
# Processing Record 5 of Set 7 | ariquemes
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | tabuk
# Processing Record 8 of Set 7 | labrea
# Processing Record 9 of Set 7 | foix
# Processing Record 10 of Set 7 | portree
# Processing Record 11 of Set 7 | gombe
# Processing Record 12 of Set 7 | tonj
# Processing Record 13 of Set 7 | kulhudhuffushi
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | muyezerskiy
# Processing Record 16 of Set 7 | ola
# Processing Record 17 of Set 7 | ambilobe
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | tongzi
# Processing Record 21 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 7 | kahta
# Processing Record 23 of Set 7 | manokwari
# Processing Record 24 of Set 7 | cap malheureux
# Processing Record 25 of Set 7 | ercis
# Processing Record 26 of Set 7 | norman wells
# Processing Record 27 of Set 7 | santiago de cao
# Processing Record 28 of Set 7 | ivanivka
# Processing Record 29 of Set 7 | jalu
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | dalby
# Processing Record 32 of Set 7 | byron bay
# Processing Record 33 of Set 7 | katherine
# Processing Record 34 of Set 7 | zhuzhou
# Processing Record 35 of Set 7 | chuguyevka
# Processing Record 36 of Set 7 | kanata
# Processing Record 37 of Set 7 | frolovo
# Processing Record 38 of Set 7 | krasnyy chikoy
# Processing Record 39 of Set 7 | caravelas
# Processing Record 40 of Set 7 | turayf
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | salinas
# Processing Record 43 of Set 7 | wainwright
# Processing Record 44 of Set 7 | dargaville
# Processing Record 45 of Set 7 | sitka
# Processing Record 46 of Set 7 | bria
# Processing Record 47 of Set 7 | alakurtti
# Processing Record 48 of Set 7 | poladpur
# Processing Record 49 of Set 7 | roswell
# Processing Record 0 of Set 8 | mount pleasant
# Processing Record 1 of Set 8 | whitehorse
# Processing Record 2 of Set 8 | ngara
# Processing Record 3 of Set 8 | matara
# Processing Record 4 of Set 8 | port elizabeth
# Processing Record 5 of Set 8 | verkhnevilyuysk
# Processing Record 6 of Set 8 | panjab
# Processing Record 7 of Set 8 | arcachon
# Processing Record 8 of Set 8 | yarim
# Processing Record 9 of Set 8 | saint-joseph
# Processing Record 10 of Set 8 | sao joao da barra
# Processing Record 11 of Set 8 | kharp
# Processing Record 12 of Set 8 | asfi
# Processing Record 13 of Set 8 | saint-pierre
# Processing Record 14 of Set 8 | alugan
# Processing Record 15 of Set 8 | nampula
# Processing Record 16 of Set 8 | selestat
# Processing Record 17 of Set 8 | dingli
# Processing Record 18 of Set 8 | moose factory
# Processing Record 19 of Set 8 | olden
# Processing Record 20 of Set 8 | tabou
# Processing Record 21 of Set 8 | capao da canoa
# Processing Record 22 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 8 | yandyki
# Processing Record 24 of Set 8 | gurupa
# Processing Record 25 of Set 8 | pangody
# Processing Record 26 of Set 8 | belmonte
# Processing Record 27 of Set 8 | manggar
# Processing Record 28 of Set 8 | puerto madryn
# Processing Record 29 of Set 8 | itum-kale
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | oblivskaya
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | chibombo
# Processing Record 34 of Set 8 | vostok
# Processing Record 35 of Set 8 | fairlie
# Processing Record 36 of Set 8 | fuling
# Processing Record 37 of Set 8 | mareeba
# Processing Record 38 of Set 8 | kapustin yar
# Processing Record 39 of Set 8 | mamallapuram
# Processing Record 40 of Set 8 | sabha
# Processing Record 41 of Set 8 | unai
# Processing Record 42 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 8 | chegdomyn
# Processing Record 44 of Set 8 | georgiyevka
# Processing Record 45 of Set 8 | yinchuan
# Processing Record 46 of Set 8 | paita
# Processing Record 47 of Set 8 | loganville
# Processing Record 48 of Set 8 | healdsburg
# Processing Record 49 of Set 8 | moron
# Processing Record 0 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 9 | la grande
# Processing Record 2 of Set 9 | bethel
# Processing Record 3 of Set 9 | hanmer springs
# Processing Record 4 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | liverpool
# Processing Record 7 of Set 9 | havelock
# Processing Record 8 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 9 | montgomery
# Processing Record 10 of Set 9 | geraldton
# Processing Record 11 of Set 9 | zwedru
# Processing Record 12 of Set 9 | sidi ali
# Processing Record 13 of Set 9 | labuhan
# Processing Record 14 of Set 9 | orimattila
# Processing Record 15 of Set 9 | haines junction
# Processing Record 16 of Set 9 | sambava
# Processing Record 17 of Set 9 | charters towers
# Processing Record 18 of Set 9 | amapa
# Processing Record 19 of Set 9 | thunder bay
# Processing Record 20 of Set 9 | pareora
# Processing Record 21 of Set 9 | sao marcos
# Processing Record 22 of Set 9 | malangali
# Processing Record 23 of Set 9 | wanning
# Processing Record 24 of Set 9 | nizwa
# Processing Record 25 of Set 9 | basoko
# Processing Record 26 of Set 9 | hopkinton
# Processing Record 27 of Set 9 | morgantown
# Processing Record 28 of Set 9 | wuwei
# Processing Record 29 of Set 9 | qarqin
# Processing Record 30 of Set 9 | dunmore town
# Processing Record 31 of Set 9 | kihurio
# Processing Record 32 of Set 9 | usinsk
# Processing Record 33 of Set 9 | palizada
# Processing Record 34 of Set 9 | winchester
# Processing Record 35 of Set 9 | tuxpan
# Processing Record 36 of Set 9 | madang
# Processing Record 37 of Set 9 | boa vista
# Processing Record 38 of Set 9 | sarakhs
# Processing Record 39 of Set 9 | puerto escondido
# Processing Record 40 of Set 9 | biak
# Processing Record 41 of Set 9 | sistranda
# Processing Record 42 of Set 9 | matay
# Processing Record 43 of Set 9 | pangai
# Processing Record 44 of Set 9 | reconquista
# Processing Record 45 of Set 9 | ponta delgada
# Processing Record 46 of Set 9 | luena
# Processing Record 47 of Set 9 | rognan
# Processing Record 48 of Set 9 | kokopo
# Processing Record 49 of Set 9 | avera
# Processing Record 0 of Set 10 | isilkul
# Processing Record 1 of Set 10 | bengkulu
# Processing Record 2 of Set 10 | souillac
# Processing Record 3 of Set 10 | egvekinot
# Processing Record 4 of Set 10 | zverinogolovskoye
# Processing Record 5 of Set 10 | fortuna
# Processing Record 6 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 10 | altay
# Processing Record 8 of Set 10 | leh
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | itoman
# Processing Record 11 of Set 10 | nouakchott
# Processing Record 12 of Set 10 | sanmihaiu de campie
# City not found. Skipping...
# Processing Record 13 of Set 10 | tignere
# Processing Record 14 of Set 10 | cascais
# Processing Record 15 of Set 10 | sakakah
# Processing Record 16 of Set 10 | hambantota
# Processing Record 17 of Set 10 | sinnamary
# Processing Record 18 of Set 10 | rawson
# Processing Record 19 of Set 10 | komsomolskiy
# Processing Record 20 of Set 10 | karoi
# Processing Record 21 of Set 10 | quesnel
# Processing Record 22 of Set 10 | adrar
# Processing Record 23 of Set 10 | khowst
# Processing Record 24 of Set 10 | elat
# Processing Record 25 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 10 | rio cuarto
# Processing Record 27 of Set 10 | hanna
# Processing Record 28 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 10 | ankara
# Processing Record 31 of Set 10 | balabac
# Processing Record 32 of Set 10 | pansemal
# Processing Record 33 of Set 10 | ibra
# Processing Record 34 of Set 10 | verkhoyansk
# Processing Record 35 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | banjar
# Processing Record 37 of Set 10 | imbituba
# Processing Record 38 of Set 10 | kalmunai
# Processing Record 39 of Set 10 | nahuatzen
# Processing Record 40 of Set 10 | san ramon
# Processing Record 41 of Set 10 | huallanca
# Processing Record 42 of Set 10 | nha trang
# Processing Record 43 of Set 10 | chifeng
# Processing Record 44 of Set 10 | luderitz
# Processing Record 45 of Set 10 | lundazi
# Processing Record 46 of Set 10 | barnstaple
# Processing Record 47 of Set 10 | bintulu
# Processing Record 48 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 10 | gallup
# Processing Record 0 of Set 11 | tual
# Processing Record 1 of Set 11 | jutai
# Processing Record 2 of Set 11 | torbay
# Processing Record 3 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 11 | batagay
# Processing Record 5 of Set 11 | vila franca do campo
# Processing Record 6 of Set 11 | waipawa
# Processing Record 7 of Set 11 | bima
# Processing Record 8 of Set 11 | irbeyskoye
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | nangomba
# Processing Record 11 of Set 11 | marsa matruh
# Processing Record 12 of Set 11 | delhi
# Processing Record 13 of Set 11 | bartica
# Processing Record 14 of Set 11 | hillsboro
# Processing Record 15 of Set 11 | nizhniy baskunchak
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | pemba
# Processing Record 18 of Set 11 | tiarei
# Processing Record 19 of Set 11 | tornabe
# Processing Record 20 of Set 11 | ambon
# Processing Record 21 of Set 11 | killam
# Processing Record 22 of Set 11 | palmer
# Processing Record 23 of Set 11 | conner
# Processing Record 24 of Set 11 | shagonar
# Processing Record 25 of Set 11 | beitbridge
# Processing Record 26 of Set 11 | kety
# Processing Record 27 of Set 11 | balkhash
# Processing Record 28 of Set 11 | mbanza-ngungu
# Processing Record 29 of Set 11 | milkovo
# Processing Record 30 of Set 11 | serpa
# Processing Record 31 of Set 11 | guiratinga
# Processing Record 32 of Set 11 | sterling
# Processing Record 33 of Set 11 | bud
# Processing Record 34 of Set 11 | sorrento
# Processing Record 35 of Set 11 | odienne
# Processing Record 36 of Set 11 | manicore
# Processing Record 37 of Set 11 | boyolangu
# Processing Record 38 of Set 11 | palauig
# Processing Record 39 of Set 11 | porto tolle
# Processing Record 40 of Set 11 | maniitsoq
# Processing Record 41 of Set 11 | leeton
# Processing Record 42 of Set 11 | saint-augustin
# Processing Record 43 of Set 11 | bar harbor
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | cravo norte
# Processing Record 46 of Set 11 | lodingen
# Processing Record 47 of Set 11 | fergus falls
# Processing Record 48 of Set 11 | arco
# Processing Record 49 of Set 11 | maneadero
# Processing Record 0 of Set 12 | mayfield
# Processing Record 1 of Set 12 | karonga
# Processing Record 2 of Set 12 | kachkanar
# Processing Record 3 of Set 12 | sheopur
# Processing Record 4 of Set 12 | roald
# Processing Record 5 of Set 12 | tigil
# Processing Record 6 of Set 12 | zhanaozen
# Processing Record 7 of Set 12 | san quintin
# Processing Record 8 of Set 12 | pinillos
# Processing Record 9 of Set 12 | palasa
# Processing Record 10 of Set 12 | chiredzi
# Processing Record 11 of Set 12 | skjervoy
# Processing Record 12 of Set 12 | quatre cocos
# Processing Record 13 of Set 12 | champerico
# Processing Record 14 of Set 12 | marawi
# Processing Record 15 of Set 12 | cape girardeau
# Processing Record 16 of Set 12 | namatanai
# Processing Record 17 of Set 12 | charleston
# Processing Record 18 of Set 12 | goderich
# Processing Record 19 of Set 12 | santiago del estero
# Processing Record 20 of Set 12 | mosquera
# Processing Record 21 of Set 12 | tutoia
# Processing Record 22 of Set 12 | shelburne
# Processing Record 23 of Set 12 | samana
# Processing Record 24 of Set 12 | kysyl-syr
# Processing Record 25 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 12 | kinston
# Processing Record 27 of Set 12 | forbes
# Processing Record 28 of Set 12 | havre-saint-pierre
# Processing Record 29 of Set 12 | fort morgan
# Processing Record 30 of Set 12 | galesong
# Processing Record 31 of Set 12 | lyuban
# Processing Record 32 of Set 12 | akureyri
# Processing Record 33 of Set 12 | krasni okny
# Processing Record 34 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 12 | flinders
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     kedrovyy  56.1667   91.8167    -12.77        98         100        0.79
# 1         lebu -37.6167  -73.6500     14.30        88           1        0.66
# 2  yellowknife  62.4560 -114.3525    -25.71        76         100        3.09
# 3    busselton -33.6500  115.3333     30.53        30          10        6.02
# 4         hami  42.8000   93.4500      0.92        35           9        1.54
#
#   Country        Date
# 0      RU  1675504501
# 1      CL  1675504501
# 2      CA  1675504502
# 3      AU  1675504503
# 4      CN  1675504504

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           kedrovyy  56.1667   91.8167    -12.77        98         100
# 1               lebu -37.6167  -73.6500     14.30        88           1
# 2        yellowknife  62.4560 -114.3525    -25.71        76         100
# 3          busselton -33.6500  115.3333     30.53        30          10
# 4               hami  42.8000   93.4500      0.92        35           9
#
#          Wind Speed Country        Date
# City_ID
# 0              0.79      RU  1675504501
# 1              0.66      CL  1675504501
# 2              3.09      CA  1675504502
# 3              6.02      AU  1675504503
# 4              1.54      CN  1675504504

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
plt.figure(figsize=(20,12))
plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]
plt.figure(figsize=(20,12))
plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]
plt.figure(figsize=(20,12))
plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]
plt.figure(figsize=(20,12))
plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    
    # Linregress function for x and y values
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Create equation of line to calculate predicted y values
    regress_values = x_values * slope + intercept

    # Get line equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create scatter plot and plot regression line
    plt.figure(figsize=(20,12))
    plt.annotate(line_eq, (x,y), fontsize=24, color="red")
    plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)
    plt.plot(x_values, regress_values, "r-")
    
    # Print r square value
    print(f"The r-value is: {r_value**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           kedrovyy  56.1667   91.8167    -12.77        98         100
# 2        yellowknife  62.4560 -114.3525    -25.71        76         100
# 4               hami  42.8000   93.4500      0.92        35           9
# 5             shache  38.4167   77.2406      4.58        44           0
# 6            qaanaaq  77.4840  -69.3632    -19.59        58          21
#
#          Wind Speed Country        Date
# City_ID
# 0              0.79      RU  1675504501
# 2              3.09      CA  1675504502
# 4              1.54      CN  1675504504
# 5              1.30      CN  1675504505
# 6              2.98      GL  1675504505

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             lebu -37.6167  -73.6500     14.30        88           1
# 3        busselton -33.6500  115.3333     30.53        30          10
# 7            vaini -21.2000 -175.2000     26.09        89          75
# 8          te anau -45.4167  167.7167     20.27        78          51
# 9            bluff -46.6000  168.3333     17.57        85          45
#
#          Wind Speed Country        Date
# City_ID
# 1              0.66      CL  1675504501
# 3              6.02      AU  1675504503
# 7              2.57      TO  1675504506
# 8              1.36      NZ  1675504506
# 9              0.55      NZ  1675504507

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Set x and y values for annotation position
x = 0
y = -20
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig5.png")
plt.show()
# Out:
# The r-value is: 0.6976394759478537

# %%
# Linear regression on Southern Hemisphere
# Set x and y values for annotation position
x = -55
y = 30
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig6.png")
plt.show()
# Out:
# The r-value is: 0.20200281831769798

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model shows a strong negative correlation between temperature and latitude in the northern hemisphere and a strong positive correlation in the southern hemisphere. Both suggesting that the closer to zero(aka-the equator), the higher the temperature. The further away from zero, the lower the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set x and y values for annotation position
x = 55
y = 25
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig7.png")
plt.show()
# Out:
# The r-value is: 0.20074594152186176

# %%
# Southern Hemisphere
# Set x and y values for annotation position
x = -50
y = 35
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig8.png")
plt.show()
# Out:
# The r-value is: 0.033007874027864675

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model shows a weak positive correlation between humidity and latitude, meaning that the further away from zero, the higher the humidity. However, the correlation is not strong enough to be considered a linear relationship.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set x and y values for annotation position
x = 55
y = 15
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig9.png")
plt.show()
# Out:
# The r-value is: 0.06964200696618408

# %%
# Southern Hemisphere
# Set x and y values for annotation position
x = -55
y = 30
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig10.png")
plt.show()
# Out:
# The r-value is: 0.34325212198438104

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model shows a weak positive correlation between cloudiness and latitude, meaning that the further away from zero, the higher the cloudiness. However, the correlation is not strong enough to be considered a linear relationship. The regression model also shows that the data is not normally distributed, and appears to be inconsistent when selecting new random samples.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Set x and y values for annotation position
x = 8
y = 15
linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig11.png")
plt.show()
# Out:
# The r-value is: 0.0010732245133869332

# %%
# Southern Hemisphere
# Set x and y values for annotation position
x = -50
y = 10
linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig12.png")
plt.show()
# Out:
# The r-value is: 0.040209322908284176

# %% [markdown]
# **Discussion about the linear relationship:** The Linear regression model shows no correlation between wind speed and latitude.
